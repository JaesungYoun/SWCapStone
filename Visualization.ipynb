# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
from scipy import io
import matplotlib.pyplot as plt
import neurokit2 as nk

# %%
all_GSR_data = pd.DataFrame()
GSR_list1 = []
mat_num = format(1, '02')
mat_name = "Data_Preprocessed_P%s/Data_Preprocessed_P%s.mat"%(mat_num,mat_num)
mat_data = io.loadmat(mat_name)
mat_data_values = mat_data['joined_data']
    
GSR_list = []
    
for j in range(20):
    temp = []
    for k in range(len(mat_data_values[0][j])):
        temp.append(mat_data_values[0][j][k][16])
    GSR_list.append(temp)
    GSR_list1.append(temp)
GSR_data = pd.DataFrame(GSR_list)
all_GSR_data = pd.concat([all_GSR_data,GSR_data])

# %%
all_GSR_data.reset_index(drop = True, inplace = True)

# %%
all_GSR_data
# Out:
#           0             1             2             3             4       \
# 0  -8.940099e+03 -1.042326e+04  9.872809e+03 -2.124787e+04 -2.521264e+04
# 1   4.005329e+05  4.001885e+05  4.040429e+05  3.981301e+05  3.973829e+05
# 2   3.814823e+05  3.814662e+05  3.781149e+05  3.835479e+05  3.841320e+05
# 3   4.188653e+05  4.194813e+05  4.106123e+05  4.246875e+05  4.263442e+05
# 4   3.314468e+05  3.313422e+05  3.293888e+05  3.326173e+05  3.334867e+05
# 5   3.390464e+05  3.386567e+05  3.463682e+05  3.346632e+05  3.330491e+05
# 6   2.589324e+05  2.586137e+05  2.584087e+05  2.589041e+05  2.587431e+05
# 7   3.519653e+05  3.527660e+05  3.476071e+05  3.553210e+05  3.562344e+05
# 8   2.451356e+05  2.438704e+05  2.578710e+05  2.365010e+05  2.336496e+05
# 9   4.760861e+05  4.760136e+05  4.775158e+05  4.754073e+05  4.747846e+05
# 10  3.228343e+05  3.230939e+05  3.206789e+05  3.247188e+05  3.249464e+05
# 11  2.326894e+05  2.296252e+05  2.688424e+05  2.083479e+05  2.005146e+05
# ...

# %%
GSR_dataset = all_GSR_data.transpose()
GSR_dataset
# Out:
#                    0              1              2              3  \
# 0       -8940.099368  400532.927288  381482.256001  418865.346224
# 1      -10423.260930  400188.462324  381466.162315  419481.304163
# 2        9872.809416  404042.898559  378114.921042  410612.264657
# 3      -21247.867932  398130.121002  383547.887441  424687.485611
# 4      -25212.644397  397382.876899  384131.978336  426344.200570
# ...              ...            ...            ...            ...
# 181797           NaN            NaN            NaN            NaN
# 181798           NaN            NaN            NaN            NaN
# 181799           NaN            NaN            NaN            NaN
# 181800           NaN            NaN            NaN            NaN
# 181801           NaN            NaN            NaN            NaN
#
#                     4              5              6              7  \
# 0       331446.826648  339046.394561  258932.398135  351965.286054
# ...

# %% [markdown]
# ## 참가자 1명에 대한 GSR 신호 시각화

# %%
plt.rcParams["figure.figsize"] = (20,20)
data = pd.DataFrame({"Video 1": GSR_dataset[0],
                     "Video 2": GSR_dataset[1],
                     "Video 3": GSR_dataset[2],
                     "Video 4": GSR_dataset[3],
                     "Video 5": GSR_dataset[4],
                     "Video 6": GSR_dataset[5],
                     "Video 7": GSR_dataset[6],
                     "Video 8": GSR_dataset[7],
                     "Video 9": GSR_dataset[8],
                     "Video 10": GSR_dataset[9],
                     "Video 11": GSR_dataset[10],
                     "Video 12": GSR_dataset[11],
                     "Video 13": GSR_dataset[12],
                     "Video 14": GSR_dataset[13],
                     "Video 15": GSR_dataset[14],
                     "Video 16": GSR_dataset[15],
                     "Video 17": GSR_dataset[16],
                     "Video 18": GSR_dataset[17],
                     "Video 19": GSR_dataset[18],
                     "Video 20": GSR_dataset[19]})


nk.signal_plot(data, subplots=True)
